# %%
import numpy as np
import pandas as pa

# %%
df = pa.read_csv("Salaries.csv")

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
print(df['Benefits'])
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 148643    0.0
# 148644    0.0
# 148645    0.0
# 148646    0.0
# 148647    0.0
# Name: Benefits, Length: 148648, dtype: float64

# %%
print(df['Benefits'].isnull())
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 148643    False
# 148644    False
# 148645    False
# 148646    False
# 148647    False
# Name: Benefits, Length: 148648, dtype: bool

# %%
print(df['Benefits'].isnull().sum())
# Out:
# 36158

# %%
print(df.isnull().sum())
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits                 0
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148648
# Agency                   0
# Status              110529
# dtype: int64

# %%
median = df['OvertimePay'].median()
df['OvertimePay'].fillna(median,inplace= True)

# %%
median= df['Benefits'].median()
df['Benefits'].fillna(median,inplace= True)

# %%
#median = df['Notes'].median()
#df['Notes'].fillna(median,inplace= True)

# %%
#AS STATUS HAS STRING VALUSE
cnt=0
for row in df['Status']:
    try:
        int(row)
        df.loc[cnt,'Status']=np.nan
    except ValueError:
        pass
    cnt+=1

# %%
print(df.isnull().sum())
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits                 0
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148648
# Agency                   0
# Status              110529
# dtype: int64

# %%
print(df['Status'].isnull())
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 148643    False
# 148644    False
# 148645    False
# 148646    False
# 148647    False
# Name: Status, Length: 148648, dtype: bool
